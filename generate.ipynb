# %%
import pickle
with open("output/saveState.pickle","rb") as open_file:
    dic = pickle.load(open_file)
    
params = dic['params']
losses = dic['loss']
num_hidden = dic['num_hidden']
character_list = dic['character_list']
vocab_size = len(character_list)

# %%
from src.functions import sample

def generate(prefix,num_char=50,temperature=0.1):
    return sample(prefix,num_char,character_list,num_hidden,params,temperature)

# %%
prefix = 'Diantre que vo'
num_char = 70

temps = [1.0,0.5,0.1,0.05,0.01]
#colors = [Fore.RED,Fore.MAGENTA,Fore.YELLOW,Fore.GREEN,Fore.BLUE]
for temp in temps:
#for temp,color  in zip(temps,colors):
    result = generate(prefix,num_char,temp)
    #print(color+'With temperature {} : '.format(temp) + result)
    print('With temperature {} : '.format(temp) + result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-0bf15fca2308> in <module>()
#       6 for temp in temps:
#       7 #for temp,color  in zip(temps,colors):
# ----> 8     result = generate(prefix,num_char,temp)
#       9     #print(color+'With temperature {} : '.format(temp) + result)
#      10     print('With temperature {} : '.format(temp) + result)
#
# <ipython-input-18-a5694bd00d82> in generate(prefix, num_char, temperature)
#       2
#       3 def generate(prefix,num_char=50,temperature=0.1):
# ----> 4     return sample(prefix,num_char,character_list,num_hidden,params,temperature)
#
# ~\Google Drive\GitHub\french-text-generator\src\functions.py in sample(prefix, num_chars, character_list, num_hidden, params, temperature)
#      83     #     4) prepare the sampled character as a one_hot (to be the next input)
#      84     for i in range(num_chars):
# ...

# %%
from colorama import Fore
print(Fore.BLUE+'blabla')
# Out:
# blabla

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(24, 8), dpi= 100)
plt.xscale('log')
#plt.yscale('log')
plt.plot(range(len(losses)),losses,'.-')
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-a22bf6759b79> in <module>()
#       5 plt.xscale('log')
#       6 #plt.yscale('log')
# ----> 7 plt.plot(range(len(losses)),losses,'.-')
#       8 plt.grid()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3159         ax.hold(hold)
#    3160     try:
# -> 3161         ret = ax.plot(*args, **kwargs)
#    3162     finally:
#    3163         ax.hold(washold)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
#    1818                                   RuntimeWarning, stacklevel=2)
# -> 1819             return func(ax, *args, **kwargs)
#    1820         pre_doc = inner.__doc__
#    1821         if pre_doc is None:
#
# ...
