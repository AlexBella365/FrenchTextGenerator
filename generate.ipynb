# %%
import pickle
with open("output/saveState.pickle","rb") as open_file:
    dic = pickle.load(open_file)
    
params = dic['params']
losses = dic['loss']
num_hidden = dic['num_hidden']
character_list = dic['character_list']
vocab_size = len(character_list)
# Out:
# /anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /anaconda/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py:46: DeprecationWarning: OpenSSL.rand is deprecated - you should use os.urandom instead
#   import OpenSSL.SSL

# %%
from src.functions import sample

def generate(prefix,num_char=50,temperature=0.1):
    return sample(prefix,num_char,character_list,num_hidden,params,temperature)

# %%
prefix = 'Diantre que vo'
num_char = 70

temps = [1.0,0.5,0.1,0.05,0.01]
#colors = [Fore.RED,Fore.MAGENTA,Fore.YELLOW,Fore.GREEN,Fore.BLUE]
for temp in temps:
#for temp,color  in zip(temps,colors):
    result = generate(prefix,num_char,temp)
    #print(color+'With temperature {} : '.format(temp) + result)
    print('With temperature {} : '.format(temp) + result)
# Out:
# With temperature 1.0 : Diantre que vous le vraieur, le ardevent, sans aller, Est-meroyez-je plus lei faire
# With temperature 0.5 : Diantre que vous savez le moins de ses yeux s'ost écapprence et que vous avez contre
# With temperature 0.1 : Diantre que vous avez le coeur d'un autre contenter de cette action de toute ma noi,
# With temperature 0.05 : Diantre que vous avez par les coeurs de ses voeux doute l'étrange en ma fille. Et vo
# With temperature 0.01 : Diantre que vous avez par les coeurs de ses voeux doute l'estre ce coup de me voir p

# %%
from colorama import Fore
print(Fore.BLUE+'blabla')
# Out:
# blabla

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(24, 8), dpi= 100)
plt.xscale('log')
#plt.yscale('log')
plt.plot(range(len(losses)),losses,'.-')
plt.grid()
